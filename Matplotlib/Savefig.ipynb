# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,3,4,5])
y=np.array([2,4,3,4,5])
plt.plot(x,y,color="r")
plt.title("Python")
plt.xlabel("X axis")
plt.ylabel("Y-axis")
plt.savefig("Line123.pdf", dpi=2000,facecolor="g",transparent=False, bbox_inches="tight")
plt.show()
